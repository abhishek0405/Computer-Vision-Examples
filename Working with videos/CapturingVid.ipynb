# %%
import cv2

# %%
cap = cv2.VideoCapture(0) # Connect to laptop webcam using 0
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
writer = cv2.VideoWriter('test.mp4',cv2.VideoWriter_fourcc(*'DIVX'),20,(width,height)) #2nd arg is default for windows,3rd is frames 
while True:
    ret,frame = cap.read()#returns a tuple where frame is what is shown in the webcam
    greyscale = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    cv2.imshow('frame',greyscale)
    writer.write(frame)
   
    if cv2.waitKey(1) & 0xFF == ord('q'):#wait one sec and check if 'q' pressed.
        break
cap.release()
writer.release()
cv2.destroyAllWindows()

# %%
import time
cap = cv2.VideoCapture('../DATA/video_capture.mp4')
while True:
    ret,frame = cap.read()
    if ret:
        time.sleep(1/20) #to slow done the frame rate so that we can watch.DONT USE IF ONLY ALTERING THE VIDEO
        cv2.imshow('frame',frame)
        if cv2.waitKey(1) & 0xFF ==ord('q'):
            break
    else:
        break
cap.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
tl_click = False
br_click = False
p1=(0,0)
p2=(0,0)
def draw(event,x,y,flags,params):
    global p1,p2,tl_click,br_click
    
    if event==cv2.EVENT_LBUTTONDOWN:   
        if (tl_click==True and br_click==True):
            tl_click = False
            br_click = False
            p1=(0,0)
            p2=(0,0)
            
        if(tl_click==False):
            p1=(x,y)
            tl_click=True
        else:
            p2=(x,y)
            br_click=True
            
            
    
        
        
cv2.namedWindow(winname='frame')
cv2.setMouseCallback('frame',draw)
while True:
    ret,frame = cap.read()
    if(tl_click):
        cv2.circle(frame,p1,1,(255,0,0),8)
    if(br_click):
         cv2.circle(frame,p2,1,(255,0,0),8)
         
    if(tl_click and br_click):
        cv2.rectangle(frame,p1,p2,(255,0,0))
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF ==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
#adding circle

import math
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
click_centre=False
click_circum=False
centre=(0,0)
rad=0
def draw(event,x,y,flags,params):
    global click_centre,rad,centre,click_circum
    
    if event==cv2.EVENT_LBUTTONDOWN:
        if(click_centre==True and click_circum==True):
            centre=(0,0)
            click_centre=False
            click_circum=False
        elif(click_centre==False):
            centre=(x,y)
            click_centre=True
        else:
            rad = int(math.sqrt((x-centre[0])**2+(y-centre[0])**2))
            click_circum=True
            
            
            
        
            
            
    
        
        
cv2.namedWindow(winname='frame')
cv2.setMouseCallback('frame',draw)
while True:
    ret,frame = cap.read()
    if(click_centre==True and click_circum==True):
        cv2.circle(frame,centre,rad,(255,0,0),4)
        
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF ==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
